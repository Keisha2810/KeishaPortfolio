# %%
#Program to calcute the GPA of students
A = 5.0
B = 4.0
C = 3.0
D = 2.0
F = 0.0
z = float(input("Score for CHM 101: "))
if 100>=z>= 70:
    print ("The GPA of CHM 101 is: ", A)
    Z=A*3
elif 69>=z >= 60:
    print ("The GPA of CHM 101 is: ", B)
    Z=B*3
elif 59>=z >= 50:
    print ("The GPA of CHM 101 is: ", C)
    Z=C*3
elif 49>=z >= 45:
    print ("The GPA of CHM 101 is: ", D)
    Z=D*3
elif 44>=z >= 0:
    print ("The GPA of CHM 101 is: ", F)
    Z=F*3
else:
    print("Your value is invalid") 
y = float(input("Score for CHM 107: "))
if 100>=y >= 70:
    print ("The GPA of CHM 107 is: ", A )
    Y=A*1
elif y >= 60:
    print ("The GPA of CHM 107 is: ", B)
    Y=B*1
elif y >= 50:
    print ("The GPA of CHM 107 is: ", C)
    Y=C*1
elif y >= 45:
    print ("The GPA of CHM 107 is: ", D)
    Y= D*1
elif y >= 0:
    print ("The GPA of CHM 107 is: ", F)
    Y=F*1
else:
    print("Your value is invalid")
x = float(input("Score for CSC 101: "))
if 100>=x >= 70:
    print ("The GPA of CSC 101 is: " ,A)
    X= A*3
elif x >= 60:
    print ("The GPA of CSC 101 is: ", B)
    X=B*3
elif x >= 50:
    print ("The GPA of CSC 101 is: ", C)
    X= C*3
elif x >= 45:
    print ("The GPA of CSC 101 is: ", D)
    X= D*3
elif x >= 0:
    print ("The GPA of CSC 101 is: " ,F)
    X=F*3
else:
    print("Your value is invalid")
w = float(input("Score for GST 101: "))
if 100>=w >= 70:
    print ("The GPA of GST 101 is: ", A)
    W= A*2
elif w >= 60:
    print ("The GPA of GST 101 is: ", B)
    W= B*2
elif w >= 50:
    print ("The GPA of GST 101 is: ", C)
    W= C*2
elif w >= 45:
    print ("The GPA of GST 101 is: ", D)
    W= D*2
elif w >= 0:
    print ("The GPA of GST 101 is: ", F)
    W= F*2
else:
    print("Your value is invalid")
v = float(input("Score for GST 103: "))
if 100>=v >= 70:
    print ("The GPA of GST 103 is : ",A)
    V=A*2
elif v >= 60:
    print ("The GPA of GST 103 is : ",B)
    V= B*2
elif v >= 50:
    print ("The GPA of GST 103 is : ",C)
    V=C*2
elif v >= 45:
    print ("The GPA of GST 103 is : ",D)
    V= D*2
elif v >= 0:
    print ("The GPA of GST 103 is : ",F)
    V= F*2
else:
    print("Your value is invalid")
u = float(input("Score for GST 108: "))
if 100>=u >= 70:
    print ("The GPA of GST 108 is : ",A)
    U=A*2
elif u >= 60:
    print ("The GPA of GST 108 is : ",B)
    U=B*2
elif u >= 50:
    print ("The GPA of GST 108 is : ",C)
    U=C*2
elif u >= 45:
    print ("The GPA of GST 108 is : ",D)
    U=D*2
elif 45>u >= 0:
    print ("The GPA of GST 108 is : ",F)
    U=F*2
else:
    print("Your value is invalid")
t = float(input("Score for MTH 101: "))
if 100>=t >= 70:
    print ("The GPA of MTH 101 is : ",A)
    T=A*3
elif 70>t >= 60:
    print ("The GPA of MTH 101 is : ",B)
    T=B*3
elif 60>t >= 50:
    print ("The GPA of MTH 101 is : ",C)
    T=C*3
elif t >= 45:
    print ("The GPA of MTH 101 is : ",D)
    T=D*3
elif 45>t >= 0:
    print ("The GPA of MTH 101 is : ",F)
    T=F*3
else:
    print("Your value is invalid")
s = float(input("Score for MTH 103: "))
if 100>= s >= 70:
    print ("The GPA of MTH 103 is : ",A)
    S=A*3
elif 70>s >= 60:
    print ("The GPA of MTH 103 is : ",B)
    S=B*3
elif 60>s >= 50:
    print ("The GPA of MTH 103 is : ",C)
    S=C*3
elif 50>s >= 45:
    print ("The GPA of MTH 103 is : ",D)
    S=D*3
elif 45>s >= 0:
    print ("The GPA of MTH 103 is : ",F)
    S=F*3
else:
    print("Your value is invalid")
r = float(input("Score for PHY 101: "))
if 100>=r >= 70:
    print ("The GPA of PHY 101 is : ",A)
    R=A*3
elif 70>r >= 60:
    print ("The GPA of PHY 101 is : ",B)
    R=B*3
elif 60>r >= 50:
    print ("The GPA of PHY 101 is : ",C)
    R=C*3
elif 50>r >= 45:
    print ("The GPA of PHY 101 is : ",D)
    R=D*3
elif 45>r >= 0:
    print ("The GPA of PHY 101 is : ",F)
    R=F*3
else:
    print("Your value is invalid")
q = float(input("Score for PHY 107: "))
if 100>=q >= 70:
    print ("The GPA of PHY 107 is : ",A)
    Q=A*1
elif 70>q >= 60:
    print ("The GPA of PHY 107 is : ",B)
    Q=B*1
elif 60>q >= 50:
    print ("The GPA of PHY 107 is : ",C)
    Q=C*1
elif 50>q >= 45:
    print ("The GPA of PHY 107 is : ",D)
    Q=D*1
elif 45>q >= 0:
    print ("The GPA of PHY 107 is : ",F)
    Q=F*1
else:
    print("Your value is invalid")
CU = 23
print("The total Credit Unit (CU) for the courses in the first semester is: ",CU)
QP=Q+R+S+T+U+V+W+X+Y+Z
print("The total Quality Point (QP) is: ",QP )
GPA = QP/CU
print("The GPA for the first year semester report is: ",GPA)
if GPA==5.0:
    print ("Your first semester grade is an A")
elif GPA >= 4.0:
    print ("Your first semester grade is a B")
elif GPA >= 3.0:
    print ("Your first semester grade is a C")
elif GPA >= 2.0:
    print ("Your first semester grade is a D")
elif GPA >= 0.0:
    print ("Your first semester grade is an F")
# Out:
# Score for CHM 101: 100
# The GPA of CHM 101 is:  5.0
# Score for CHM 107: 78
# The GPA of CHM 107 is:  5.0
# Score for CSC 101: 45
# The GPA of CSC 101 is:  2.0
# Score for GST 101: 67
# The GPA of GST 101 is:  4.0
# Score for GST 103: 34
# The GPA of GST 103 is :  0.0
# Score for GST 108: 99
# The GPA of GST 108 is :  5.0
# Score for MTH 101: 67
# The GPA of MTH 101 is :  4.0
# Score for MTH 103: 34
# The GPA of MTH 103 is :  0.0
# Score for PHY 101: 23
# The GPA of PHY 101 is :  0.0
# Score for PHY 107: 78
# The GPA of PHY 107 is :  5.0
# The total Credit Unit (CU) for the courses in the first semester is:  23
# The total Quality Point (QP) is:  61.0
# The GPA for the first year semester report is:  2.652173913043478
# Your first semester grade is a D
